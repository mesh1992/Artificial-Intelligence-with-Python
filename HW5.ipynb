# %% [markdown]
# <a href="https://colab.research.google.com/github/mesh1992/Artificial-Intelligence-with-Python/blob/master/HW5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
data = np.array([[1,0,0,7,'Apple'],
            [0,1,0,20,'Watermelon'], 
            [1,0,0,1,'Cherry'],
            [0,1,0,7.5,'Apple'],
            [1,0,0,1,'Strawvberry'],
            [1,0,0,0.8,'Cherry']])

# %%
print(data)
# Out:
# [['1' '0' '0' '7' 'Apple']
#  ['0' '1' '0' '20' 'Watermelon']
#  ['1' '0' '0' '1' 'Cherry']
#  ['0' '1' '0' '7.5' 'Apple']
#  ['1' '0' '0' '1' 'Strawvberry']
#  ['1' '0' '0' '0.8' 'Cherry']]

# %%
X = data[:,:4]
y = data[:,4]
print(X)
print(y)
# Out:
# [['1' '0' '0' '7']
#  ['0' '1' '0' '20']
#  ['1' '0' '0' '1']
#  ['0' '1' '0' '7.5']
#  ['1' '0' '0' '1']
#  ['1' '0' '0' '0.8']]
# ['Apple' 'Watermelon' 'Cherry' 'Apple' 'Strawvberry' 'Cherry']

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(bootstrap='true',max_features='sqrt',max_depth=4)
model.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap='true', max_depth=4, max_features='sqrt')

# %%
model = RandomForestClassifier(bootstrap='true',max_features='sqrt',max_depth=4)
model.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap='true', max_depth=4, max_features='sqrt')

# %%
test = np.array([[1,0,0,10]])
print(test)
# Out:
# [[ 1  0  0 10]]

# %%
model.predict(test)
# Out:
# array(['Apple'], dtype='<U32')

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
estimator = model.estimators_[5]
plt.figure(figsize=(25,10))
a = plot_tree(estimator,
              feature_names = ['Red', 'Green','Blue','Size'],
                class_names = ['Apple','Watermelon','Cherry','Strawberry'],
              filled=True,
              rounded=True,
              fontsize=14)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math



y=[] # to store the values of the function
x=np.arange(-2,2,0.05) # stroing the x values in the x - numpy array
for i in range(len(x)):
     x[i]=round(x[i],2)

print(x) # printing the x values obtained in the range [-2,2] with step of 0.05

for i in x:
    y.append(round(math.e -i**2 + 0.01*(math.cos(200*i)),4)) # calculating the y value of the function f(x)
    
print(y) # printing the y value 

print('\nMaximum value of the function is :',end=" ") 
print(max(y)) # maximum value of the function

plt.xlabel("x ---->")
plt.ylabel('Y=f(x)')

plt.scatter(x,y)
plt.plot(x,y,'r')
plt.show()
# Out:
# [-2.   -1.95 -1.9  -1.85 -1.8  -1.75 -1.7  -1.65 -1.6  -1.55 -1.5  -1.45
#  -1.4  -1.35 -1.3  -1.25 -1.2  -1.15 -1.1  -1.05 -1.   -0.95 -0.9  -0.85
#  -0.8  -0.75 -0.7  -0.65 -0.6  -0.55 -0.5  -0.45 -0.4  -0.35 -0.3  -0.25
#  -0.2  -0.15 -0.1  -0.05  0.    0.05  0.1   0.15  0.2   0.25  0.3   0.35
#   0.4   0.45  0.5   0.55  0.6   0.65  0.7   0.75  0.8   0.85  0.9   0.95
#   1.    1.05  1.1   1.15  1.2   1.25  1.3   1.35  1.4   1.45  1.5   1.55
#   1.6   1.65  1.7   1.75  1.8   1.85  1.9   1.95]
# ...
